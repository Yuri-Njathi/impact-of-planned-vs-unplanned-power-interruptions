# %% [markdown]
# Merge population data with counties

# %%
import pandas as pd

def get_merged_df(df1_path,df2_path,common="CODE",new_name="kenya_census_data.csv",how="outer",path=True):
    if path:
        df1 = pd.read_csv(df1_path)
        df2 = pd.read_csv(df2_path)
    
    merged = pd.merge(df1, df2, on=common, how=how) 
    print('Visualize Dataframe : \n',merged.head())
    print('\n Dataframe shape= ',merged.shape)
    merged.to_csv(new_name, index=False)
    return merged

# %%
#merge population data with 
merged = get_merged_df(df1_path="/kaggle/input/counties-data/Kenya_counties_census_data_v2.csv",df2_path="/kaggle/input/counties-data/kenya_counties_v3.csv",common="CODE",new_name="kenya_census_data.csv",how="outer")
# Out:
# Visualize Dataframe :
#     UNIT_AREA  UNIT_PERIM  COUNT  COUNTY_NAM  CODE  MALE_POP  FEMALE_POP  \
# 0   0.023356    0.967209     34     Mombasa     1    610257      598046
# 1   0.758340    4.378790     83       Kwale     2    425121      441681
# 2   0.391775    3.909102    107      Kilifi     3    704089      749673
# 3   3.185316   10.410747     92  Tana River     4    158550      157391
# 4   0.743918    3.771571     40        Lamu     5     76103       67813
#
#    INTERSEX  TOTAL_POP  POP_DENSIT  \
# 0        30    1208333  517.354427
# 1        18     866820   11.430493
# 2        25    1453787   37.107702
# 3         2     315943    0.991873
# 4         4     143920    1.934622
#
#                                             geometry      County ISO_Code  \
# 0                                                NaN     Mombasa    KE-28
# 1                                                NaN       Kwale    KE-19
# 2                                                NaN      Kilifi    KE-14
# 3                                                NaN  Tana River    KE-40
# 4  POLYGON ((642522.8810571186 9778754.915494535,...        Lamu    KE-21
#
#    Latitude  Longitude
# 0   -4.0435    40.0000
# 1   -3.9737    39.1521
# 2   -3.5107    39.9093
# 3   -1.6500    40.0500
# 4   -2.2717    40.9020
#
#  Dataframe shape=  (47, 15)

# %%
#some counties not named the same
merged["County"] == merged['COUNTY_NAM']
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27    False
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# dtype: bool

# %%
merged['names_equal'] = merged["County"] == merged['COUNTY_NAM'];

# %%
merged[merged['names_equal'] != True]
# Out:
#     UNIT_AREA  UNIT_PERIM  COUNT       COUNTY_NAM  CODE  MALE_POP  FEMALE_POP  \
# 12   0.089623    1.706179     75    Tharaka Nithi    13    193764      199406
# 20   0.080291    2.185837     74         Murang'a    21    523940      532669
# 27   0.116074    2.554823     87  Elgeyo Marakwet    28    227317      227151
#
#     INTERSEX  TOTAL_POP  POP_DENSIT  \
# 12         7     393177   43.870100
# 20        31    1056640  131.601300
# 27        12     454480   39.154333
#
#                                              geometry           County  \
# 12                                                NaN    Tharaka-Nithi
# 20  POLYGON ((248959.90077712593 9937560.724792477...         Murang`a
# 27                                                NaN  Elgeyo-Marakwet
#
#    ISO_Code  Latitude  Longitude  names_equal
# 12    KE-41   -0.3333    37.7167        False
# 20    KE-29   -0.7833    37.0500        False
# 27    KE-05    1.0500    35.5000        False

# %%
merged = get_merged_df(df1_path="/kaggle/input/counties-data/Kenya_census_percentage_type_of_lighting_fuel_per_county.csv",df2_path="/kaggle/working/kenya_census_data.csv",common="CODE",new_name="kenya_census_data.csv",how="outer")
# Out:
# Visualize Dataframe :
#     CODE    County_x Conventional Households  Mains Electricity  \
# 0     1     MOMBASA                 376,295               85.9
# 1     2       KWALE                 172,802               31.5
# 2     3      KILIFI                 297,990               38.5
# 3     4  TANA RIVER                  66,984               25.6
# 4     5        LAMU                  34,231               43.2
#
#    Paraffin Pressure\n lamp  Paraffin Lantern  Paraffin Tin\n lamp  Gas Lamp  \
# 0                       0.5               2.7                  6.3       0.1
# 1                       0.5               6.0                 29.5       0.2
# 2                       0.6               6.1                 26.7       0.1
# 3                       0.2               2.4                  7.1       0.5
# 4                       0.2               3.6                  7.2       0.1
#
#    Wood  Solar  ...  MALE_POP  FEMALE_POP  INTERSEX  TOTAL_POP  POP_DENSIT  \
# 0   0.0    1.5  ...    610257      598046        30    1208333  517.354427
# 1   1.7   22.8  ...    425121      441681        18     866820   11.430493
# 2   1.3   20.0  ...    704089      749673        25    1453787   37.107702
# 3   6.8   20.9  ...    158550      157391         2     315943    0.991873
# 4   1.4   28.3  ...     76103       67813         4     143920    1.934622
#
#                                             geometry    County_y ISO_Code  \
# 0                                                NaN     Mombasa    KE-28
# 1                                                NaN       Kwale    KE-19
# 2                                                NaN      Kilifi    KE-14
# 3                                                NaN  Tana River    KE-40
# 4  POLYGON ((642522.8810571186 9778754.915494535,...        Lamu    KE-21
#
#    Latitude  Longitude
# 0   -4.0435    40.0000
# 1   -3.9737    39.1521
# 2   -3.5107    39.9093
# 3   -1.6500    40.0500
# 4   -2.2717    40.9020
#
# [5 rows x 28 columns]
#
#  Dataframe shape=  (47, 28)

# %%
merged.columns
# Out:
# Index(['CODE', 'County_x', 'Conventional Households', 'Mains Electricity',
#        'Paraffin Pressure\n lamp', 'Paraffin Lantern', 'Paraffin Tin\n lamp',
#        'Gas Lamp', 'Wood', 'Solar', 'Torch/ Spotlight-Solar\n Charged',
#        'Torch/ Spot\n light-Dry cells', 'Candle', 'Battery (Car/Charged)',
#        'UNIT_AREA', 'UNIT_PERIM', 'COUNT', 'COUNTY_NAM', 'MALE_POP',
#        'FEMALE_POP', 'INTERSEX', 'TOTAL_POP', 'POP_DENSIT', 'geometry',
#        'County_y', 'ISO_Code', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
# help(merged)

# %%
merged[['CODE', 'County_x', 'Conventional Households', 'Mains Electricity',
       'UNIT_AREA', 'UNIT_PERIM', 'COUNT', 'COUNTY_NAM', 'TOTAL_POP', 'POP_DENSIT', 'geometry',
       'County_y', 'ISO_Code', 'Latitude', 'Longitude']]
# Out:
#     CODE         County_x Conventional Households  Mains Electricity  \
# 0      1          MOMBASA                 376,295               85.9
# 1      2            KWALE                 172,802               31.5
# 2      3           KILIFI                 297,990               38.5
# 3      4       TANA RIVER                  66,984               25.6
# 4      5             LAMU                  34,231               43.2
# 5      6     TAITA/TAVETA                  94,468               47.6
# 6      7          GARISSA                 138,940               23.5
# 7      8            WAJIR                 126,878               14.1
# 8      9          MANDERA                 123,954               15.7
# 9     10         MARSABIT                  76,689               21.3
# 10    11           ISIOLO                  53,217               40.6
# 11    12             MERU                 423,931               40.2
# 12    13    THARAKA•NITHI                 109,450               34.7
# 13    14             EMBU                 182,427               47.0
# 14    15            KITUI                 261,814               17.1
# 15    16         MACHAKOS                 399,523               48.3
# 16    17          MAKUENI                 243,979               20.4
# 17    18        NYANDARUA                 178,224               41.3
# 18    19            NYERI                 244,564               71.8
# 19    20        KIRINYAGA                 203,576               65.3
# 20    21         MURANG'A                 317,496               60.5
# 21    22           KIAMBU                 792,333               91.7
# 22    23          TURKANA                 162,627                8.6
# 23    24       WEST POKOT                 115,761               11.8
# 24    25          SAMBURU                  63,951               14.8
# 25    26      TRANS NZOIA                 222,989               37.9
# 26    27      UASIN GISHU                 301,110               63.8
# 27    28  ELGEYO-MARAKWET                  99,119               24.3
# 28    29            NANDI                 199,040               30.7
# 29    30          BARINGO                 141,877               28.3
# 30    31         LAIKIPIA                 145,776               42.2
# 31    32           NAKURU                 598,237               64.4
# 32    33            NAROK                 238,115               19.7
# 33    34          KAJIADO                 313,218               67.4
# 34    35          KERICHO                 205,932               44.9
# 35    36            BOMET                 187,230               22.1
# 36    37         KAKAMEGA                 432,284               25.1
# 37    38           VIHIGA                 143,288               38.4
# 38    39          BUNGOMA                 357,714               21.6
# 39    40            BUSIA                 197,944               26.1
# 40    41            SIAYA                 249,341               19.7
# 41    42           KISUMU                 296,846               52.6
# 42    43         HOMA BAY                 260,290               18.4
# 43    44           MIGORI                 238,133               23.3
# 44    45            KISII                 307,254               39.3
# 45    46          NYAMIRA                 150,499               42.9
# 46    47     NAIROBI CITY               1,494,676               96.5
#
#     UNIT_AREA  UNIT_PERIM  COUNT       COUNTY_NAM  TOTAL_POP  POP_DENSIT  \
# 0    0.023356    0.967209     34          Mombasa    1208333  517.354427
# 1    0.758340    4.378790     83            Kwale     866820   11.430493
# 2    0.391775    3.909102    107           Kilifi    1453787   37.107702
# 3    3.185316   10.410747     92       Tana River     315943    0.991873
# 4    0.743918    3.771571     40             Lamu     143920    1.934622
# 5    1.394121    5.835375     77     Taita Taveta     340671    2.443626
# 6    2.873839    9.461324     65          Garissa     841353    2.927627
# 7    4.606753   10.063932     96            Wajir     781263    1.695908
# 8    2.114494    7.340257    100          Mandera     867457    4.102433
# 9    5.425059   10.593218     63         Marsabit     459785    0.847521
# 10   2.063787   10.331290     44           Isiolo     268002    1.298593
# 11   0.247808    2.522790    146             Meru    1545714   62.375468
# 12   0.089623    1.706179     75    Tharaka Nithi     393177   43.870100
# 13   0.059311    1.503596     52             Embu     608599  102.611489
# 14   1.652880    7.601730    187            Kitui    1136187    6.873984
# 15   0.491152    6.216976    225         Machakos    1421932   28.950956
# 16   0.664615    6.066572    191          Makueni     987653   14.860528
# 17   0.265387    3.642147     79        Nyandarua     638289   24.051253
# 18   0.270912    3.159364    192            Nyeri     759164   28.022531
# 19   0.119853    2.024245     81        Kirinyaga     610411   50.929973
# 20   0.080291    2.185837     74         Murang'a    1056640  131.601300
# 21   0.108970    2.275224    112           Kiambu    2417735  221.871616
# 22   5.708368   14.461664    157          Turkana     926976    1.623890
# 23   0.756408    4.809351    197       West Pokot     621241    8.213041
# 24   1.707896    8.135254    108          Samburu     310327    1.817013
# 25   0.201947    2.530345     55      Trans Nzoia     990341   49.039649
# 26   0.275902    4.061775     99      Uasin Gishu    1163186   42.159390
# 27   0.116074    2.554823     87  Elgeyo Marakwet     454480   39.154333
# 28   0.116509    1.899620    124            Nandi     885711   76.020822
# 29   0.696210    5.468653    172          Baringo     666763    9.577039
# 30   0.774795    5.480793     65         Laikipia     518560    6.692867
# 31   0.607338    6.590186    152           Nakuru    2162202   35.601296
# 32   1.222793    6.935685    105            Narok    1157873    9.469084
# 33   1.779241    7.457146    120          Kajiado    1117840    6.282679
# 34   0.106271    2.197821    106          Kericho     901777   84.856358
# 35   0.110070    2.030379    109            Bomet     875689   79.557463
# 36   0.076771    2.023831     78         Kakamega    1867579  243.266207
# 37   0.045527    1.463902    117           Vihiga     590013  129.596283
# 38   0.167501    2.892534    108          Bungoma    1670570   99.734927
# 39   0.102212    2.492476     99            Busia     893681   87.434059
# 40   0.161656    1.858956     49            Siaya     993183   61.438054
# 41   0.080829    1.670120     69           Kisumu    1155574  142.965272
# 42   0.102025    1.939555     77         Homa Bay    1131950  110.948297
# 43   0.047272    1.085838     47           Migori    1116436  236.172787
# 44   0.054016    0.995855     75            Kisii    1266860  234.534212
# 45   0.072892    1.537310     76          Nyamira     605576   83.078527
# 46   0.057502    1.688550    107          Nairobi    4397073  764.681750
#
#                                              geometry         County_y  \
# 0                                                 NaN          Mombasa
# 1                                                 NaN            Kwale
# 2                                                 NaN           Kilifi
# 3                                                 NaN       Tana River
# 4   POLYGON ((642522.8810571186 9778754.915494535,...             Lamu
# 5   POLYGON ((354711.8827239537 9647736.937326128,...     Taita Taveta
# 6                                                 NaN          Garissa
# 7                                                 NaN            Wajir
# 8                                                 NaN          Mandera
# 9                                                 NaN         Marsabit
# 10                                                NaN           Isiolo
# 11                                                NaN             Meru
# 12                                                NaN    Tharaka-Nithi
# 13                                                NaN             Embu
# 14                                                NaN            Kitui
# 15                                                NaN         Machakos
# 16                                                NaN          Makueni
# 17                                                NaN        Nyandarua
# 18                                                NaN            Nyeri
# 19                                                NaN        Kirinyaga
# 20  POLYGON ((248959.90077712593 9937560.724792477...         Murang`a
# 21                                                NaN           Kiambu
# 22                                                NaN          Turkana
# 23                                                NaN       West Pokot
# 24                                                NaN          Samburu
# 25                                                NaN      Trans Nzoia
# 26                                                NaN      Uasin Gishu
# 27                                                NaN  Elgeyo-Marakwet
# 28                                                NaN            Nandi
# 29                                                NaN          Baringo
# 30                                                NaN         Laikipia
# 31                                                NaN           Nakuru
# 32                                                NaN            Narok
# 33                                                NaN          Kajiado
# 34                                                NaN          Kericho
# 35                                                NaN            Bomet
# 36                                                NaN         Kakamega
# 37                                                NaN           Vihiga
# 38                                                NaN          Bungoma
# 39                                                NaN            Busia
# 40                                                NaN            Siaya
# 41                                                NaN           Kisumu
# 42                                                NaN         Homa Bay
# 43                                                NaN           Migori
# 44                                                NaN            Kisii
# 45                                                NaN          Nyamira
# 46                                                NaN          Nairobi
#
#    ISO_Code  Latitude  Longitude
# 0     KE-28   -4.0435    40.0000
# 1     KE-19   -3.9737    39.1521
# 2     KE-14   -3.5107    39.9093
# 3     KE-40   -1.6500    40.0500
# 4     KE-21   -2.2717    40.9020
# 5     KE-39   -3.3167    38.4833
# 6     KE-07   -0.4534    39.6460
# 7     KE-46    1.7500    40.0667
# 8     KE-27    3.9373    41.8569
# 9     KE-25    2.3333    37.9833
# 10    KE-09    0.3524    37.5822
# 11    KE-12    0.3556    37.8088
# 12    KE-41   -0.3333    37.7167
# 13    KE-06   -0.5333    37.4500
# 14    KE-15   -1.3667    38.0167
# 15    KE-22   -1.5167    37.2667
# 16    KE-23   -1.7500    37.6167
# 17    KE-35   -0.3167    36.6500
# 18    KE-36   -0.4167    37.0500
# 19    KE-13   -0.6000    37.3500
# 20    KE-29   -0.7833    37.0500
# 21    KE-11   -1.1667    36.8333
# 22    KE-43    3.1224    35.5970
# 23    KE-47    1.5000    35.3333
# 24    KE-37    1.2000    36.9000
# 25    KE-42    1.0167    35.0000
# 26    KE-44    0.6000    35.3500
# 27    KE-05    1.0500    35.5000
# 28    KE-30    0.1833    35.1000
# 29    KE-01    0.4667    35.9833
# 30    KE-20    0.3333    36.5833
# 31    KE-31   -0.3031    36.0800
# 32    KE-32   -1.0833    35.8667
# 33    KE-10   -1.8500    36.7833
# 34    KE-16   -0.3677    35.2830
# 35    KE-02   -0.7833    35.3333
# 36    KE-09    0.2833    34.7500
# 37    KE-45    0.0833    34.7500
# 38    KE-03    0.5667    34.5667
# 39    KE-04    0.4500    34.1000
# 40    KE-38    0.0667    34.2667
# 41    KE-17   -0.0917    34.7670
# 42    KE-08   -0.5333    34.4500
# 43    KE-24   -1.0667    34.4667
# 44    KE-18   -0.6833    34.7667
# 45    KE-34   -0.5667    34.9333
# 46    KE-30   -1.2864    36.8172

# %%
merged["County_x"] == merged['County_y']
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# dtype: bool
